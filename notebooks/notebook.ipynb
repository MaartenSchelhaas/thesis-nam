# %%
import pandas as pd 

df = pd.read_csv(r'C:\Users\maart\OneDrive\Documenten\Universiteit\Scriptie\python_repo\thesis-nam\datasets\raw\compas-scores-two-years.csv')

df['length_of_stay'] = pd.to_datetime(df['c_jail_out']) - pd.to_datetime(df['c_jail_in'])

column_list = [
    'age',
    'c_charge_degree',
    'length_of_stay',
    'priors_count',
    'race',
    'sex',
    'two_year_recid'        
    ]

df = df[column_list]

print(df)
# Out:
#       age c_charge_degree   length_of_stay  priors_count              race  \
# 0      69               F  0 days 23:37:38             0             Other
# 1      34               F 10 days 01:51:26             0  African-American
# 2      24               F  1 days 02:03:30             4  African-American
# 3      23               F              NaT             1  African-American
# 4      43               F              NaT             2             Other
# ...   ...             ...              ...           ...               ...
# 7209   23               F  1 days 21:40:53             0  African-American
# 7210   23               F  1 days 20:49:58             0  African-American
# 7211   57               F  1 days 02:01:45             0             Other
# 7212   33               M  1 days 04:12:02             3  African-American
# 7213   23               F  1 days 23:02:42             2          Hispanic
#
#          sex  two_year_recid
# 0       Male               0
# ...
